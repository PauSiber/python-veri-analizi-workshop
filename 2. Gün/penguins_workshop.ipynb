# %% [markdown]
# # 🧪 Uygulamalı Çalışma: Penguins Veri Seti Üzerinden Keşifsel Veri Analizi

# %% [markdown]
# ### 🔹 1. Veri Setini Yükle ve Temel Gözlem
# Veri setini yükleme

# %%
import seaborn as sns
import pandas as pd

penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# - Veri setindeki kaç tür penguen var?
# - Hangi kolonlarda eksik veri var?
# - Bu veri seti ne tür bir problem için kullanılabilir?

# %% [markdown]
# ### 🔹 2. Cinsiyet ve Tür Dağılımı

# %%
import matplotlib.pyplot as plt
sns.countplot(x="species", hue="sex", data=penguins)
plt.title("Penguen Türlerine Göre Cinsiyet Dağılımı")
plt.show()

# %% [markdown]
# - Hangi türde erkek/dişi farkı daha belirgin?
# - Bu fark neden olabilir?

# %% [markdown]
# ### 🔹 3. Vücut Ağırlığı Dağılımı

# %%
sns.histplot(data=penguins, x="body_mass_g", kde=True)
plt.title("Penguen Vücut Ağırlığı Dağılımı")
plt.show()

# %% [markdown]
# - Ortalama ağırlık yaklaşık kaç gram?
# - Dağılım normal mi? Simetrik mi?

# %% [markdown]
# ### 🔹 4. Türlere Göre Ağırlık Karşılaştırması

# %%
sns.boxplot(x="species", y="body_mass_g", data=penguins)
plt.title("Türlere Göre Vücut Ağırlığı Kutu Grafiği")
plt.show()

# %% [markdown]
# - En ağır tür hangisi?
# - Kutu grafikteki uç değerler ne anlama gelir?

# %% [markdown]
# ### 🔹 5. Flipper Length ve Body Mass İlişkisi

# %%
sns.scatterplot(data=penguins, x="flipper_length_mm", y="body_mass_g", hue="species")
plt.title("Flipper Uzunluğu vs Vücut Ağırlığı")
plt.show()

# %% [markdown]
# - Aralarında korelasyon var mı?
# - Türlere göre kümelenme farkı var mı?

# %% [markdown]
# ### 🔹 6. Korelasyon Haritası

# %%
sns.heatmap(penguins.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Değişkenler Arası Korelasyon")
plt.show()

# %% [markdown]
# - En güçlü ilişki hangi iki değişken arasında?
# - Negatif korelasyon var mı?

# %% [markdown]
# ### 🔹 7. Pairplot Gösterimi

# %%
sns.pairplot(penguins, hue="species")
plt.suptitle("Çoklu Değişken Görselleştirme", y=1.02)
plt.show()

# %% [markdown]
# - Türler arasında net ayrım yapılan değişkenler hangileri?

# %% [markdown]
# ### 🔹 8. Mini Görevler

# %% [markdown]
# `Adalara göre yüzgeç uzunluğu dağılımını çiz.`

# %%
sns.boxplot(data=penguins, x="island", y="flipper_length_mm", palette="Set2")
plt.title("Adalara Göre Flipper Uzunluğu Dağılımı")
plt.show()
# Out:
# /tmp/ipykernel_9115/962947273.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x="island", y="flipper_length_mm", palette="Set2")

# %% [markdown]
# `Sadece erkek penguenler için ağırlık histogramı oluştur.`

# %%
male_penguins = penguins[penguins["sex"] == "Male"]
sns.histplot(data=male_penguins, x="body_mass_g", bins=20, kde=True, color="skyblue")
plt.title("Erkek Penguenlerin Ağırlık Dağılımı")
plt.xlabel("Vücut Ağırlığı (g)")
plt.show()

# %% [markdown]
# `Cinsiyete göre boxplot ile yüzgeç uzunluğu karşılaştır.`

# %%
sns.boxplot(data=penguins, x="sex", y="flipper_length_mm", palette="pastel")
plt.title("Cinsiyete Göre Flipper Uzunluğu")
plt.show()
# Out:
# /tmp/ipykernel_9115/4261308036.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x="sex", y="flipper_length_mm", palette="pastel")

# %% [markdown]
# `Yüzgeç uzunluğu ve gaga uzunluğu arasındaki ilişkiyi görselleştir.`

# %%
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", style="sex")
plt.title("Flipper Uzunluğu vs Gaga Uzunluğu")
plt.show()

# %% [markdown]
# `Eksik verileri ortalamayla doldurup tekrar scatter plot çiz.`

# %%
penguins_filled = penguins.copy()
penguins_filled["bill_length_mm"].fillna(penguins["bill_length_mm"].mean(), inplace=True)
penguins_filled["flipper_length_mm"].fillna(penguins["flipper_length_mm"].mean(), inplace=True)

# Scatter plot
sns.scatterplot(data=penguins_filled, x="flipper_length_mm", y="bill_length_mm", hue="species")
plt.title("Ortalamayla Doldurulmuş Veride Flipper vs Gaga Uzunluğu")
plt.show()
# Out:
# /tmp/ipykernel_9115/1808485804.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   penguins_filled["bill_length_mm"].fillna(penguins["bill_length_mm"].mean(), inplace=True)
# /tmp/ipykernel_9115/1808485804.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Penguenlerin türlerine göre ortalama flipper uzunluklarını hesaplayın.

# %%
pivot_table = penguins.pivot_table(values="flipper_length_mm", index="species", aggfunc="mean")
print(pivot_table)
# Out:
#            flipper_length_mm
# species
# Adelie            189.953642
# Chinstrap         195.823529
# Gentoo            217.186992

# %% [markdown]
# **groupby: Veriyi daha derinlemesine analiz etmek, örneğin her bir grup üzerinde farklı hesaplamalar yapmak, filtrelemek, ya da gruplar üzerinde daha karmaşık işlemler yapmak istiyorsanız groupby daha uygundur.**
#
# **pivot_table: Veriyi satırlara ve sütunlara göre özetlemek, karşılaştırmak ya da çok değişkenli analizler yapmak istiyorsanız pivot_table daha uygun olacaktır.**

# %% [markdown]
# Ağırlık ve flipper uzunluğu arasındaki ilişkiyi korelasyon ısı haritası ile görselleştirin.

# %%
correlation_matrix = penguins[["body_mass_g", "flipper_length_mm", "bill_length_mm", "bill_depth_mm"]].corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korelasyon Isı Haritası")
plt.show()
