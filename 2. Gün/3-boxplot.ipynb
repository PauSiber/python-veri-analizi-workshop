# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
# hangi günler daha fazla kazanç var

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "day", data = df);

# %%
# sabah mı akşam mı kazanç daha fazla

# %%
sns.boxplot(x = "time", y = "total_bill", hue = "time", data = df);

# %%
# kişi sayısına göre kazanç nasıl değişiyor

# %%
sns.boxplot(x = "size", y = "total_bill", hue = "size", data = df);

# %%
# günlere göre cinsiyet ne kadar etki ediyor

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "sex", data = df);
